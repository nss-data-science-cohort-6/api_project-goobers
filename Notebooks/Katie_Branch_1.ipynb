# %%
import requests
import matplotlib.pyplot as plt
import json
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd

# %%
endpoint = "https://data.nashville.gov/resource/2u6v-ujjs.json"

response = requests.get(endpoint)

# %%
params={'offense_description': 'BURGLARY- AGGRAVATED', '$where': "incident_reported between '2022-01-01' and '2022-09-30'", '$limit': 50000}
response = requests.get(endpoint)

# %%
response.text
# Out:
# '[{"primary_key":"20220641257_11","incident_number":"20220641257","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-14T16:00:00.000","incident_reported":"2022-10-14T16:01:00.000","incident_location":"4343 4343","latitude":"36.207","longitude":"-86.612","zip_code":"37076","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"810","offense_description":"LOST PROPERTY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"W","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.612,36.207]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@computed_region_p6sk_2acq":"27",":@computed_region_gxvr_9jxz":"44"}\n,{"primary_key":"20220641203_11","incident_number":"20220641203","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-14T15:31:00.000","incident_reported":"2022-10-14T15:31:00.000","incident_location":"5800 5800","latitude":"36.183","longitude":"-86.588","zip_code":"37076","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"810","offense_description":"LOST PROPERTY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.588,36.183]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@computed_region_p6sk_2acq":"26",":@computed_region_gxvr_9jxz":"44"}\n,{"primary_key":"20220632390_11","incident_number":"20220632390","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-10T16:49:00.000","incident_reported":"2022-10-10T16:49:00.000","incident_location":"309 309","latitude":"36.072","longitude":"-86.582","zip_code":"37013","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"740","offense_description":"POLICE INQUIRY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.582,36.072]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"33",":@computed_region_gxvr_9jxz":"15"}\n,{"primary_key":"20220632346_11","incident_number":"20220632346","report_type":"W","report_type_description":"WITNESS","incident_status_code":"O","incident_status_description":"OPEN","investigation_status":"Open","incident_occurred":"2022-10-10T05:30:00.000","incident_reported":"2022-10-10T16:28:00.000","incident_location":"QUAIL VALLEY RD","latitude":"36.14","longitude":"-86.64","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"290","offense_description":"DAMAGE PROP - PRIVATE","weapon_primary":"07","weapon_description":"CLUB","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.64,36.14]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7": ...

# %%
response
# Out:
# <Response [200]>

# %%
res = response.json()
res
# Out:
# [{'primary_key': '20220641257_11',
#   'incident_number': '20220641257',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-14T16:00:00.000',
#   'incident_reported': '2022-10-14T16:01:00.000',
#   'incident_location': '4343 4343',
#   'latitude': '36.207',
#   'longitude': '-86.612',
#   'zip_code': '37076',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.612, 36.207]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '27',
#   ':@computed_region_gxvr_9jxz': '44'},
#  {'primary_key': '20220641203_11',
#   'incident_number': '20220641203',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-14T15:31:00.000',
#   'incident_reported': '2022-10-14T15:31:00.000',
#   'incident_location': '5800 5800',
#   'latitude': '36.183',
#   'longitude': '-86.588',
#   'zip_code': '37076',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.588, 36.183]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '26',
#   ':@computed_region_gxvr_9jxz': '44'},
#  {'primary_key': '20220632390_11',
#   'incident_number': '20220632390',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-10T16:49:00.000',
#   'incident_reported': '2022-10-10T16:49:00.000',
#   'incident_location': '309 309',
#   'latitude': '36.072',
#   'longitude': '-86.582',
#   'zip_code': '37013',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.582, 36.072]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220632346_11',
#   'incident_number': '20220632346',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-10T05:30:00.000',
#   'incident_reported': '2022-10-10T16:28:00.000',
#   'incident_location': 'QUAIL VALLEY RD',
#   'latitude': '36.14',
#   'longitude': '-86.64',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.14]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'primary_key': '20220631992_11',
#   'incident_number': '20220631992',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-09T21:00:00.000',
#   'incident_reported': '2022-10-10T13:28:00.000',
#   'incident_location': 'CLEARLAKE DR',
#   'latitude': '36.05',
#   'longitude': '-86.6',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6, 36.05]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220533143_11',
#   'incident_number': '20220533143',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-22T22:00:00.000',
#   'incident_reported': '2022-10-22T22:21:00.000',
#   'incident_location': '451 451',
#   'zip_code': '37213',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220533009_11',
#   'incident_number': '20220533009',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T19:54:00.000',
#   'incident_reported': '2022-10-22T21:58:00.000',
#   'incident_location': '4TH AV S',
#   'latitude': '36.16',
#   'longitude': '-86.77',
#   'location_code': '17',
#   'location_description': 'LIQUOR STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '29'},
#  {'primary_key': '20220532970_11',
#   'incident_number': '20220532970',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-22T17:00:00.000',
#   'incident_reported': '2022-10-22T21:11:00.000',
#   'incident_location': '& GALLATIN AV',
#   'zip_code': '37206',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'TRANSPORT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532969_11',
#   'incident_number': '20220532969',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T15:30:00.000',
#   'incident_reported': '2022-10-22T20:00:00.000',
#   'incident_location': 'BELTON',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532922_11',
#   'incident_number': '20220532922',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T17:30:00.000',
#   'incident_reported': '2022-10-22T18:46:00.000',
#   'incident_location': 'NOLENSVILLE',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220532872_11',
#   'incident_number': '20220532872',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T16:00:00.000',
#   'incident_reported': '2022-10-22T18:21:00.000',
#   'incident_location': 'HILLSIDE',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532849_11',
#   'incident_number': '20220532849',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-16T19:41:00.000',
#   'incident_reported': '2022-10-22T17:32:00.000',
#   'incident_location': 'CHARLOTTE',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220532842_11',
#   'incident_number': '20220532842',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T12:00:00.000',
#   'incident_reported': '2022-10-22T18:09:00.000',
#   'incident_location': 'LAKEFORD',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'A',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532836_11',
#   'incident_number': '20220532836',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T13:00:00.000',
#   'incident_reported': '2022-10-22T18:35:00.000',
#   'incident_location': 'NOLENSVILLE',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '695',
#   'offense_description': 'UNKNOWN DEATH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220532800_11',
#   'incident_number': '20220532800',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-01T12:00:00.000',
#   'incident_reported': '2022-10-22T17:13:00.000',
#   'incident_location': 'TERMINAL DR',
#   'latitude': '36.14',
#   'longitude': '-86.67',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY - MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.67, 36.14]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'primary_key': '20220532751_11',
#   'incident_number': '20220532751',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T15:36:00.000',
#   'incident_reported': '2022-10-22T17:16:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '26A',
#   'offense_description': 'THEFT OF SERVICES-  $500 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220532681_11',
#   'incident_number': '20220532681',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T19:00:00.000',
#   'incident_reported': '2022-10-22T15:36:00.000',
#   'incident_location': '51ST AV N',
#   'latitude': '36.15',
#   'longitude': '-86.85',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'A',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.85, 36.15]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '10',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'primary_key': '20220532615_11',
#   'incident_number': '20220532615',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-08-09T00:00:00.000',
#   'incident_reported': '2022-10-22T18:00:00.000',
#   'incident_location': 'MARGARET',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532613_11',
#   'incident_number': '20220532613',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T20:00:00.000',
#   'incident_reported': '2022-10-22T13:52:00.000',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532609_11',
#   'incident_number': '20220532609',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T18:00:00.000',
#   'incident_reported': '2022-10-22T14:34:00.000',
#   'incident_location': 'OPRYLAND',
#   'location_code': '39',
#   'location_description': 'Arena/Stadium/Fairgrounds/Coliseum',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220532606_11',
#   'incident_number': '20220532606',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T14:00:00.000',
#   'incident_reported': '2022-10-22T14:43:00.000',
#   'incident_location': 'PATIO',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532586_11',
#   'incident_number': '20220532586',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T03:00:00.000',
#   'incident_reported': '2022-10-22T13:27:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '23A',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220532582_11',
#   'incident_number': '20220532582',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T13:30:00.000',
#   'incident_reported': '2022-10-22T13:20:00.000',
#   'incident_location': 'OPRY MILLS',
#   'latitude': '36.21',
#   'longitude': '-86.69',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'FRAUD -  ILLEG USE OF CREDIT CARDS',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.69, 36.21]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '8',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'primary_key': '20220532555_11',
#   'incident_number': '20220532555',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T18:00:00.000',
#   'incident_reported': '2022-10-22T13:07:00.000',
#   'incident_location': 'MATTHEW',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532552_11',
#   'incident_number': '20220532552',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T00:30:00.000',
#   'incident_reported': '2022-10-22T12:57:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220532525_11',
#   'incident_number': '20220532525',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T13:30:00.000',
#   'incident_reported': '2022-10-22T12:44:00.000',
#   'incident_location': 'OPRY MILLS',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220532499_11',
#   'incident_number': '20220532499',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T20:30:00.000',
#   'incident_reported': '2022-10-22T12:24:00.000',
#   'incident_location': 'S 5TH ST',
#   'latitude': '36.17',
#   'longitude': '-86.76',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGLARY- AGGRAVATED',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.17]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '4'},
#  {'primary_key': '20220532378_11',
#   'incident_number': '20220532378',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T15:16:00.000',
#   'incident_reported': '2022-10-22T09:48:00.000',
#   'incident_location': 'LINCOYA BAY',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $500 OR LESS',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532309_11',
#   'incident_number': '20220532309',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T06:51:00.000',
#   'incident_reported': '2022-10-22T08:59:00.000',
#   'incident_location': 'SCOTT VALLEY',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532274_11',
#   'incident_number': '20220532274',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T23:30:00.000',
#   'incident_reported': '2022-10-22T08:05:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '23A',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220532197_11',
#   'incident_number': '20220532197',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-22T06:15:00.000',
#   'incident_reported': '2022-10-22T06:50:00.000',
#   'incident_location': '203 203',
#   'zip_code': '37211',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '685',
#   'offense_description': 'DEATH NATURAL',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220532136_23',
#   'incident_number': '20220532136',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T03:50:00.000',
#   'incident_reported': '2022-10-22T05:37:00.000',
#   'incident_location': 'HILLSBORO PKE',
#   'latitude': '36.11',
#   'longitude': '-86.81',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'primary_key': '20220532136_12',
#   'incident_number': '20220532136',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T03:50:00.000',
#   'incident_reported': '2022-10-22T05:37:00.000',
#   'incident_location': 'HILLSBORO PKE',
#   'latitude': '36.11',
#   'longitude': '-86.81',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '120',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'primary_key': '20220532136_11',
#   'incident_number': '20220532136',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T03:50:00.000',
#   'incident_reported': '2022-10-22T05:37:00.000',
#   'incident_location': 'HILLSBORO PKE',
#   'latitude': '36.11',
#   'longitude': '-86.81',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '120',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'primary_key': '20220532098_11',
#   'incident_number': '20220532098',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T03:15:00.000',
#   'incident_reported': '2022-10-22T06:06:00.000',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220532042_11',
#   'incident_number': '20220532042',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-22T00:30:00.000',
#   'incident_reported': '2022-10-22T06:44:00.000',
#   'incident_location': 'CHURCH ST',
#   'latitude': '36.15',
#   'longitude': '-86.79',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY - MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.79, 36.15]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220532018_11',
#   'incident_number': '20220532018',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T22:30:00.000',
#   'incident_reported': '2022-10-22T01:57:00.000',
#   'incident_location': 'GALLATIN',
#   'location_code': '7',
#   'location_description': 'CONVENIENCE STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220531955_11',
#   'incident_number': '20220531955',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-22T00:01:00.000',
#   'incident_reported': '2022-10-22T01:25:00.000',
#   'incident_location': '4813 4813',
#   'zip_code': '37214',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '620',
#   'offense_description': 'ACCIDENTAL INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531767_11',
#   'incident_number': '20220531767',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-21T17:00:00.000',
#   'incident_reported': '2022-10-22T01:23:00.000',
#   'incident_location': '632 632',
#   'zip_code': '37115',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '685',
#   'offense_description': 'DEATH NATURAL',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531682_11',
#   'incident_number': '20220531682',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T17:55:00.000',
#   'incident_reported': '2022-10-21T23:35:00.000',
#   'incident_location': 'ABBOTT MARTIN RD',
#   'location_code': '12',
#   'location_description': 'GROCERY, SUPERMARKET',
#   'offense_number': '1',
#   'offense_nibrs': '23A',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531577_11',
#   'incident_number': '20220531577',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T19:21:00.000',
#   'incident_reported': '2022-10-21T23:41:00.000',
#   'incident_location': 'CHARLOTTE',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'THEFT OF MERCHANDISE 5TH - $1,000 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220531563_11',
#   'incident_number': '20220531563',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T20:00:00.000',
#   'incident_reported': '2022-10-21T20:35:00.000',
#   'incident_location': '4TH AV S',
#   'latitude': '36.16',
#   'longitude': '-86.77',
#   'location_code': '17',
#   'location_description': 'LIQUOR STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '29'},
#  {'primary_key': '20220531448_11',
#   'incident_number': '20220531448',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T15:53:00.000',
#   'incident_reported': '2022-10-21T18:55:00.000',
#   'incident_location': 'RICHARDS',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220531433_11',
#   'incident_number': '20220531433',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T18:00:00.000',
#   'incident_reported': '2022-10-21T18:51:00.000',
#   'incident_location': 'CONCORD HILLS',
#   'location_code': '5',
#   'location_description': 'COMMERCIAL, OFFICE BUILDING',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220531422_11',
#   'incident_number': '20220531422',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T07:00:00.000',
#   'incident_reported': '2022-10-21T18:30:00.000',
#   'incident_location': '23RD AV N',
#   'latitude': '36.17',
#   'longitude': '-86.81',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.17]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '25',
#   ':@computed_region_gxvr_9jxz': '51'},
#  {'primary_key': '20220531415_11',
#   'incident_number': '20220531415',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-21T18:01:00.000',
#   'incident_reported': '2022-10-21T18:41:00.000',
#   'incident_location': '515 515',
#   'zip_code': '37203',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531392_11',
#   'incident_number': '20220531392',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-18T10:45:00.000',
#   'incident_reported': '2022-10-21T18:08:00.000',
#   'incident_location': 'SAWYER BROWN',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220531364_11',
#   'incident_number': '20220531364',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-12T17:00:00.000',
#   'incident_reported': '2022-10-21T18:37:00.000',
#   'incident_location': 'TUSCULUM',
#   'location_code': '6',
#   'location_description': 'CONSTRUCTION SITE',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'LARCENY - (FREE TEXT)',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531334_11',
#   'incident_number': '20220531334',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-21T10:00:00.000',
#   'incident_reported': '2022-10-21T17:23:00.000',
#   'incident_location': 'MERCER',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'LARC - POSTAL',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531327_11',
#   'incident_number': '20220531327',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T22:00:00.000',
#   'incident_reported': '2022-10-21T17:24:00.000',
#   'incident_location': 'OLD HARDING',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220531323_11',
#   'incident_number': '20220531323',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-21T15:45:00.000',
#   'incident_reported': '2022-10-21T22:51:00.000',
#   'incident_location': '609 609',
#   'zip_code': '37211',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'TRANSPORT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
# ...
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T02:00:00.000',
#   'incident_reported': '2022-10-17T02:49:00.000',
#   'incident_location': '315 315',
#   'zip_code': '37219',
#   'location_code': '14',
#   'location_description': 'HOTEL, MOTEL, ETC.',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220522040_11',
#   'incident_number': '20220522040',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T02:08:00.000',
#   'incident_reported': '2022-10-17T02:59:00.000',
#   'incident_location': '2609 2609',
#   'zip_code': '37207',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220522039_11',
#   'incident_number': '20220522039',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-17T00:47:00.000',
#   'incident_reported': '2022-10-17T02:24:00.000',
#   'incident_location': 'HARDING PL',
#   'latitude': '36.08',
#   'longitude': '-86.7',
#   'location_code': '25',
#   'location_description': 'SERVICE, GAS STATION',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'THEFT OF MERCHANDISE- $1,000 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.08]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '28',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220522037_11',
#   'incident_number': '20220522037',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T01:45:00.000',
#   'incident_reported': '2022-10-17T02:23:00.000',
#   'incident_location': '2827 2827',
#   'latitude': '36.088',
#   'longitude': '-86.609',
#   'zip_code': '37217',
#   'location_code': '7',
#   'location_description': 'CONVENIENCE STORE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'U',
#   'victim_description': 'UNKNOWN',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.609, 36.088]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'primary_key': '20220522017_11',
#   'incident_number': '20220522017',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T02:39:00.000',
#   'incident_reported': '2022-10-17T02:39:00.000',
#   'incident_location': '& WILOWEN DR',
#   'zip_code': '37210',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220522016_11',
#   'incident_number': '20220522016',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T01:40:00.000',
#   'incident_reported': '2022-10-17T02:20:00.000',
#   'incident_location': '900 900',
#   'latitude': '36.208',
#   'longitude': '-86.742',
#   'zip_code': '37216',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.742, 36.208]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '13',
#   ':@computed_region_gxvr_9jxz': '23'},
#  {'primary_key': '20220522012_11',
#   'incident_number': '20220522012',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T00:18:00.000',
#   'incident_reported': '2022-10-17T02:37:00.000',
#   'incident_location': '837 837',
#   'latitude': '36.137',
#   'longitude': '-86.7',
#   'zip_code': '37217',
#   'location_code': '14',
#   'location_description': 'HOTEL, MOTEL, ETC.',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.137]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'primary_key': '20220521998_11',
#   'incident_number': '20220521998',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-16T08:00:00.000',
#   'incident_reported': '2022-10-17T02:16:00.000',
#   'incident_location': 'MORNINGWOOD LN',
#   'latitude': '36.01',
#   'longitude': '-86.63',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.01]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220521971_11',
#   'incident_number': '20220521971',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T01:00:00.000',
#   'incident_reported': '2022-10-17T01:35:00.000',
#   'incident_location': '5320 5320',
#   'latitude': '36.064',
#   'longitude': '-86.586',
#   'zip_code': '37013',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.586, 36.064]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220521964_11',
#   'incident_number': '20220521964',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-16T02:00:00.000',
#   'incident_reported': '2022-10-17T01:27:00.000',
#   'incident_location': '639 639',
#   'latitude': '36.154',
#   'longitude': '-86.777',
#   'zip_code': '37203',
#   'location_code': '11',
#   'location_description': 'GOVERNMENT, PUBLIC BUILDING',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.777, 36.154]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220521963_11',
#   'incident_number': '20220521963',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T17:30:00.000',
#   'incident_reported': '2022-10-17T02:04:00.000',
#   'incident_location': 'OLD HICKORY BLVD',
#   'latitude': '36.09',
#   'longitude': '-86.92',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGLARY- AGGRAVATED',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.92, 36.09]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '32',
#   ':@computed_region_gxvr_9jxz': '32'},
#  {'primary_key': '20220521923_11',
#   'incident_number': '20220521923',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-17T00:00:00.000',
#   'incident_reported': '2022-10-17T01:05:00.000',
#   'incident_location': 'ROSA L PARKS BLVD',
#   'latitude': '36.18',
#   'longitude': '-86.8',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.18]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '51'},
#  {'primary_key': '20220521890_11',
#   'incident_number': '20220521890',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-16T23:49:00.000',
#   'incident_reported': '2022-10-17T01:11:00.000',
#   'incident_location': '1622 1622',
#   'latitude': '36.18',
#   'longitude': '-86.767',
#   'zip_code': '37207',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.767, 36.18]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '13',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'primary_key': '20220521876_11',
#   'incident_number': '20220521876',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-16T19:40:00.000',
#   'incident_reported': '2022-10-17T00:30:00.000',
#   'incident_location': 'CLINTON ST',
#   'latitude': '36.16',
#   'longitude': '-86.8',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220521873_32',
#   'incident_number': '20220521873',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-17T01:49:00.000',
#   'incident_reported': '2022-10-17T01:49:00.000',
#   'incident_location': '3696 3696',
#   'latitude': '36.152',
#   'longitude': '-86.625',
#   'zip_code': '37214',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '3',
#   'offense_nibrs': '35B',
#   'offense_description': 'DRUG PARAPHERNALIA- UNLAWFUL USE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.625, 36.152]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '7',
#   ':@computed_region_gxvr_9jxz': '38'}]

# %%
burglaries = pd.DataFrame(res)
burglaries
# Out:
#         primary_key incident_number report_type report_type_description  \
# 0    20220641257_11     20220641257           W                 WITNESS
# 1    20220641203_11     20220641203           W                 WITNESS
# 2    20220632390_11     20220632390           W                 WITNESS
# 3    20220632346_11     20220632346           W                 WITNESS
# 4    20220631992_11     20220631992           W                 WITNESS
# ..              ...             ...         ...                     ...
# 995  20220521963_11     20220521963           D              DISPATCHED
# 996  20220521923_11     20220521923           D              DISPATCHED
# 997  20220521890_11     20220521890           D              DISPATCHED
# 998  20220521876_11     20220521876           D              DISPATCHED
# 999  20220521873_32     20220521873           D              DISPATCHED
#
#     incident_status_code incident_status_description investigation_status  \
# 0                      U                   UNFOUNDED               Closed
# 1                      U                   UNFOUNDED               Closed
# 2                      U                   UNFOUNDED               Closed
# 3                      O                        OPEN                 Open
# 4                      O                        OPEN                 Open
# ..                   ...                         ...                  ...
# 995                    O                        OPEN                 Open
# 996                    O                        OPEN                 Open
# 997                    U                   UNFOUNDED               Closed
# 998                    O                        OPEN                 Open
# 999                    A           CLEARED BY ARREST               Closed
#
#            incident_occurred        incident_reported  incident_location  ...  \
# 0    2022-10-14T16:00:00.000  2022-10-14T16:01:00.000          4343 4343  ...
# 1    2022-10-14T15:31:00.000  2022-10-14T15:31:00.000          5800 5800  ...
# 2    2022-10-10T16:49:00.000  2022-10-10T16:49:00.000            309 309  ...
# 3    2022-10-10T05:30:00.000  2022-10-10T16:28:00.000    QUAIL VALLEY RD  ...
# 4    2022-10-09T21:00:00.000  2022-10-10T13:28:00.000       CLEARLAKE DR  ...
# ..                       ...                      ...                ...  ...
# 995  2022-10-15T17:30:00.000  2022-10-17T02:04:00.000   OLD HICKORY BLVD  ...
# 996  2022-10-17T00:00:00.000  2022-10-17T01:05:00.000  ROSA L PARKS BLVD  ...
# 997  2022-10-16T23:49:00.000  2022-10-17T01:11:00.000          1622 1622  ...
# 998  2022-10-16T19:40:00.000  2022-10-17T00:30:00.000         CLINTON ST  ...
# 999  2022-10-17T01:49:00.000  2022-10-17T01:49:00.000          3696 3696  ...
#
#            victim_description victim_gender victim_race victim_ethnicity  \
# 0    INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 1    INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 2    INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 3    INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4    INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# ..                        ...           ...         ...              ...
# 995  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 996  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 997  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 998  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 999                   SOCIETY           NaN         NaN              NaN
#
#     victim_county_resident                                    mapped_location  \
# 0                 RESIDENT  {'type': 'Point', 'coordinates': [-86.612, 36....
# 1                 RESIDENT  {'type': 'Point', 'coordinates': [-86.588, 36....
# 2                 RESIDENT  {'type': 'Point', 'coordinates': [-86.582, 36....
# 3                 RESIDENT  {'type': 'Point', 'coordinates': [-86.64, 36.14]}
# 4             NON RESIDENT   {'type': 'Point', 'coordinates': [-86.6, 36.05]}
# ..                     ...                                                ...
# 995               RESIDENT  {'type': 'Point', 'coordinates': [-86.92, 36.09]}
# 996               RESIDENT   {'type': 'Point', 'coordinates': [-86.8, 36.18]}
# 997               RESIDENT  {'type': 'Point', 'coordinates': [-86.767, 36....
# 998           NON RESIDENT   {'type': 'Point', 'coordinates': [-86.8, 36.16]}
# 999                    NaN  {'type': 'Point', 'coordinates': [-86.625, 36....
#
#     :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                             1                           2
# 1                             1                           2
# 2                             1                           1
# 3                             1                           2
# 4                             1                           2
# ..                          ...                         ...
# 995                           1                           1
# 996                           1                           1
# 997                           1                           1
# 998                           1                           1
# 999                           1                           2
#
#     :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz
# 0                            27                          44
# 1                            26                          44
# 2                            33                          15
# 3                             6                          38
# 4                            33                          15
# ..                          ...                         ...
# 995                          32                          32
# 996                          20                          51
# 997                          13                          16
# 998                          20                          40
# 999                           7                          38
#
# [1000 rows x 33 columns]

# %%
burglaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   primary_key                  1000 non-null   object
#  1   incident_number              1000 non-null   object
#  2   report_type                  1000 non-null   object
#  3   report_type_description      885 non-null    object
#  4   incident_status_code         1000 non-null   object
#  5   incident_status_description  1000 non-null   object
#  6   investigation_status         1000 non-null   object
#  7   incident_occurred            1000 non-null   object
#  8   incident_reported            1000 non-null   object
#  9   incident_location            964 non-null    object
#  10  latitude                     712 non-null    object
#  11  longitude                    712 non-null    object
#  12  zip_code                     370 non-null    object
#  13  location_code                1000 non-null   object
#  14  location_description         1000 non-null   object
#  15  offense_number               1000 non-null   object
#  16  offense_nibrs                1000 non-null   object
#  17  offense_description          1000 non-null   object
#  18  weapon_primary               970 non-null    object
#  19  weapon_description           970 non-null    object
#  20  victim_number                1000 non-null   object
#  21  domestic_related             1000 non-null   bool
#  22  victim_type                  1000 non-null   object
#  23  victim_description           1000 non-null   object
#  24  victim_gender                809 non-null    object
#  25  victim_race                  809 non-null    object
#  26  victim_ethnicity             809 non-null    object
#  27  victim_county_resident       810 non-null    object
#  28  mapped_location              712 non-null    object
#  29  :@computed_region_wvby_4s8j  712 non-null    object
#  30  :@computed_region_3aw5_2wv7  712 non-null    object
#  31  :@computed_region_p6sk_2acq  712 non-null    object
#  32  :@computed_region_gxvr_9jxz  712 non-null    object
# dtypes: bool(1), object(32)
# memory usage: 251.1+ KB

# %%
burglaries["latitude"] = pd.to_numeric(burglaries["latitude"])
burglaries["longitude"] = pd.to_numeric(burglaries["longitude"])

# %%
burglaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   primary_key                  1000 non-null   object
#  1   incident_number              1000 non-null   object
#  2   report_type                  1000 non-null   object
#  3   report_type_description      885 non-null    object
#  4   incident_status_code         1000 non-null   object
#  5   incident_status_description  1000 non-null   object
#  6   investigation_status         1000 non-null   object
#  7   incident_occurred            1000 non-null   object
#  8   incident_reported            1000 non-null   object
#  9   incident_location            964 non-null    object
#  10  latitude                     712 non-null    float64
#  11  longitude                    712 non-null    float64
#  12  zip_code                     370 non-null    object
#  13  location_code                1000 non-null   object
#  14  location_description         1000 non-null   object
#  15  offense_number               1000 non-null   object
#  16  offense_nibrs                1000 non-null   object
#  17  offense_description          1000 non-null   object
#  18  weapon_primary               970 non-null    object
#  19  weapon_description           970 non-null    object
#  20  victim_number                1000 non-null   object
#  21  domestic_related             1000 non-null   bool
#  22  victim_type                  1000 non-null   object
#  23  victim_description           1000 non-null   object
#  24  victim_gender                809 non-null    object
#  25  victim_race                  809 non-null    object
#  26  victim_ethnicity             809 non-null    object
#  27  victim_county_resident       810 non-null    object
#  28  mapped_location              712 non-null    object
#  29  :@computed_region_wvby_4s8j  712 non-null    object
#  30  :@computed_region_3aw5_2wv7  712 non-null    object
#  31  :@computed_region_p6sk_2acq  712 non-null    object
#  32  :@computed_region_gxvr_9jxz  712 non-null    object
# dtypes: bool(1), float64(2), object(30)
# memory usage: 251.1+ KB

# %%
burglaries["geometry"] = burglaries.apply(lambda x: Point((x['longitude'], x['latitude'])), axis=1)
# Out:
# C:\Users\hpunc\ANACONDA\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
burglaries.head()
# Out:
#       primary_key incident_number report_type report_type_description  \
# 0  20220641257_11     20220641257           W                 WITNESS
# 1  20220641203_11     20220641203           W                 WITNESS
# 2  20220632390_11     20220632390           W                 WITNESS
# 3  20220632346_11     20220632346           W                 WITNESS
# 4  20220631992_11     20220631992           W                 WITNESS
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    U                   UNFOUNDED               Closed
# 1                    U                   UNFOUNDED               Closed
# 2                    U                   UNFOUNDED               Closed
# 3                    O                        OPEN                 Open
# 4                    O                        OPEN                 Open
#
#          incident_occurred        incident_reported incident_location  ...  \
# 0  2022-10-14T16:00:00.000  2022-10-14T16:01:00.000         4343 4343  ...
# 1  2022-10-14T15:31:00.000  2022-10-14T15:31:00.000         5800 5800  ...
# 2  2022-10-10T16:49:00.000  2022-10-10T16:49:00.000           309 309  ...
# 3  2022-10-10T05:30:00.000  2022-10-10T16:28:00.000   QUAIL VALLEY RD  ...
# 4  2022-10-09T21:00:00.000  2022-10-10T13:28:00.000      CLEARLAKE DR  ...
#
#    victim_gender  victim_race victim_ethnicity victim_county_resident  \
# 0              F            W     Non-Hispanic               RESIDENT
# 1              F            B     Non-Hispanic               RESIDENT
# 2              F            B     Non-Hispanic               RESIDENT
# 3              F            B     Non-Hispanic               RESIDENT
# 4              F            B     Non-Hispanic           NON RESIDENT
#
#                                      mapped_location  \
# 0  {'type': 'Point', 'coordinates': [-86.612, 36....
# 1  {'type': 'Point', 'coordinates': [-86.588, 36....
# 2  {'type': 'Point', 'coordinates': [-86.582, 36....
# 3  {'type': 'Point', 'coordinates': [-86.64, 36.14]}
# 4   {'type': 'Point', 'coordinates': [-86.6, 36.05]}
#
#   :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                           1                           2
# 1                           1                           2
# 2                           1                           1
# 3                           1                           2
# 4                           1                           2
#
#   :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz  \
# 0                          27                          44
# 1                          26                          44
# 2                          33                          15
# 3                           6                          38
# 4                          33                          15
#
#                  geometry
# 0  POINT (-86.612 36.207)
# 1  POINT (-86.588 36.183)
# 2  POINT (-86.582 36.072)
# 3    POINT (-86.64 36.14)
# 4     POINT (-86.6 36.05)
#
# [5 rows x 34 columns]

# %%
census_tracts = gpd.read_file("../data/tl_2020_47_tract.shp")
census_tracts
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 0         47      175  925200  47175925200     9252     Census Tract 9252
# 1         47      175  925000  47175925000     9250     Census Tract 9250
# 2         47      003  950201  47003950201  9502.01  Census Tract 9502.01
# 3         47      003  950202  47003950202  9502.02  Census Tract 9502.02
# 4         47      093  003300  47093003300       33       Census Tract 33
# ...      ...      ...     ...          ...      ...                   ...
# 1696      47      073  050501  47073050501   505.01   Census Tract 505.01
# 1697      47      073  050601  47073050601   506.01   Census Tract 506.01
# 1698      47      073  050602  47073050602   506.02   Census Tract 506.02
# 1699      47      073  050502  47073050502   505.02   Census Tract 505.02
# 1700      47      073  050503  47073050503   505.03   Census Tract 505.03
#
#       MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0     G5020        S  227429512  1667739  +35.7438100  -085.4940227
# 1     G5020        S  480712883  1225717  +35.6695378  -085.4220628
# 2     G5020        S  121774227        0  +35.6517480  -086.5575518
# 3     G5020        S  110617191   700793  +35.5845755  -086.5790796
# 4     G5020        S    5860088   229299  +36.0020586  -083.8371218
# ...     ...      ...        ...      ...          ...           ...
# 1696  G5020        S   83355996        0  +36.5659159  -082.7715246
# 1697  G5020        S   23847669   177932  +36.5836443  -082.6318663
# 1698  G5020        S   23386546   668716  +36.5467218  -082.6458382
# 1699  G5020        S   32873931   311980  +36.5332207  -082.7586081
# 1700  G5020        S   17050728   568444  +36.5225397  -082.6970280
#
#                                                geometry
# 0     POLYGON ((-85.61516 35.76106, -85.61509 35.761...
# 1     POLYGON ((-85.60513 35.70854, -85.60511 35.708...
# 2     POLYGON ((-86.64406 35.64029, -86.64375 35.642...
# 3     POLYGON ((-86.66377 35.58189, -86.66367 35.582...
# 4     POLYGON ((-83.86208 35.99255, -83.86207 35.992...
# ...                                                 ...
# 1696  POLYGON ((-82.85011 36.54107, -82.84955 36.541...
# 1697  POLYGON ((-82.68939 36.58793, -82.68936 36.588...
# 1698  POLYGON ((-82.69446 36.54856, -82.69445 36.548...
# 1699  POLYGON ((-82.82242 36.52006, -82.82171 36.520...
# 1700  POLYGON ((-82.73162 36.52804, -82.73108 36.528...
#
# [1701 rows x 13 columns]

# %%
burglaries = gpd.GeoDataFrame(burglaries, geometry=burglaries["geometry"], crs=census_tracts.crs)
burglaries
# Out:
#         primary_key incident_number report_type report_type_description  \
# 0    20220641257_11     20220641257           W                 WITNESS
# 1    20220641203_11     20220641203           W                 WITNESS
# 2    20220632390_11     20220632390           W                 WITNESS
# 3    20220632346_11     20220632346           W                 WITNESS
# 4    20220631992_11     20220631992           W                 WITNESS
# ..              ...             ...         ...                     ...
# 995  20220521963_11     20220521963           D              DISPATCHED
# 996  20220521923_11     20220521923           D              DISPATCHED
# 997  20220521890_11     20220521890           D              DISPATCHED
# 998  20220521876_11     20220521876           D              DISPATCHED
# 999  20220521873_32     20220521873           D              DISPATCHED
#
#     incident_status_code incident_status_description investigation_status  \
# 0                      U                   UNFOUNDED               Closed
# 1                      U                   UNFOUNDED               Closed
# 2                      U                   UNFOUNDED               Closed
# 3                      O                        OPEN                 Open
# 4                      O                        OPEN                 Open
# ..                   ...                         ...                  ...
# 995                    O                        OPEN                 Open
# 996                    O                        OPEN                 Open
# 997                    U                   UNFOUNDED               Closed
# 998                    O                        OPEN                 Open
# 999                    A           CLEARED BY ARREST               Closed
#
#            incident_occurred        incident_reported  incident_location  ...  \
# 0    2022-10-14T16:00:00.000  2022-10-14T16:01:00.000          4343 4343  ...
# 1    2022-10-14T15:31:00.000  2022-10-14T15:31:00.000          5800 5800  ...
# 2    2022-10-10T16:49:00.000  2022-10-10T16:49:00.000            309 309  ...
# 3    2022-10-10T05:30:00.000  2022-10-10T16:28:00.000    QUAIL VALLEY RD  ...
# 4    2022-10-09T21:00:00.000  2022-10-10T13:28:00.000       CLEARLAKE DR  ...
# ..                       ...                      ...                ...  ...
# 995  2022-10-15T17:30:00.000  2022-10-17T02:04:00.000   OLD HICKORY BLVD  ...
# 996  2022-10-17T00:00:00.000  2022-10-17T01:05:00.000  ROSA L PARKS BLVD  ...
# 997  2022-10-16T23:49:00.000  2022-10-17T01:11:00.000          1622 1622  ...
# 998  2022-10-16T19:40:00.000  2022-10-17T00:30:00.000         CLINTON ST  ...
# 999  2022-10-17T01:49:00.000  2022-10-17T01:49:00.000          3696 3696  ...
#
#      victim_gender  victim_race victim_ethnicity victim_county_resident  \
# 0                F            W     Non-Hispanic               RESIDENT
# 1                F            B     Non-Hispanic               RESIDENT
# 2                F            B     Non-Hispanic               RESIDENT
# 3                F            B     Non-Hispanic               RESIDENT
# 4                F            B     Non-Hispanic           NON RESIDENT
# ..             ...          ...              ...                    ...
# 995              F            W     Non-Hispanic               RESIDENT
# 996              F            B     Non-Hispanic               RESIDENT
# 997              F            B     Non-Hispanic               RESIDENT
# 998              F            W     Non-Hispanic           NON RESIDENT
# 999            NaN          NaN              NaN                    NaN
#
#                                        mapped_location  \
# 0    {'type': 'Point', 'coordinates': [-86.612, 36....
# 1    {'type': 'Point', 'coordinates': [-86.588, 36....
# 2    {'type': 'Point', 'coordinates': [-86.582, 36....
# 3    {'type': 'Point', 'coordinates': [-86.64, 36.14]}
# 4     {'type': 'Point', 'coordinates': [-86.6, 36.05]}
# ..                                                 ...
# 995  {'type': 'Point', 'coordinates': [-86.92, 36.09]}
# 996   {'type': 'Point', 'coordinates': [-86.8, 36.18]}
# 997  {'type': 'Point', 'coordinates': [-86.767, 36....
# 998   {'type': 'Point', 'coordinates': [-86.8, 36.16]}
# 999  {'type': 'Point', 'coordinates': [-86.625, 36....
#
#     :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                             1                           2
# 1                             1                           2
# 2                             1                           1
# 3                             1                           2
# 4                             1                           2
# ..                          ...                         ...
# 995                           1                           1
# 996                           1                           1
# 997                           1                           1
# 998                           1                           1
# 999                           1                           2
#
#     :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz  \
# 0                            27                          44
# 1                            26                          44
# 2                            33                          15
# 3                             6                          38
# 4                            33                          15
# ..                          ...                         ...
# 995                          32                          32
# 996                          20                          51
# 997                          13                          16
# 998                          20                          40
# 999                           7                          38
#
#                        geometry
# 0    POINT (-86.61200 36.20700)
# 1    POINT (-86.58800 36.18300)
# 2    POINT (-86.58200 36.07200)
# 3    POINT (-86.64000 36.14000)
# 4    POINT (-86.60000 36.05000)
# ..                          ...
# 995  POINT (-86.92000 36.09000)
# 996  POINT (-86.80000 36.18000)
# 997  POINT (-86.76700 36.18000)
# 998  POINT (-86.80000 36.16000)
# 999  POINT (-86.62500 36.15200)
#
# [1000 rows x 34 columns]

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %%
endpoint = "https://data.nashville.gov/resource/2u6v-ujjs.json"

response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"primary_key":"20220641257_11","incident_number":"20220641257","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-14T16:00:00.000","incident_reported":"2022-10-14T16:01:00.000","incident_location":"4343 4343","latitude":"36.207","longitude":"-86.612","zip_code":"37076","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"810","offense_description":"LOST PROPERTY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"W","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.612,36.207]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@computed_region_p6sk_2acq":"27",":@computed_region_gxvr_9jxz":"44"}\n,{"primary_key":"20220641203_11","incident_number":"20220641203","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-14T15:31:00.000","incident_reported":"2022-10-14T15:31:00.000","incident_location":"5800 5800","latitude":"36.183","longitude":"-86.588","zip_code":"37076","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"810","offense_description":"LOST PROPERTY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.588,36.183]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"2",":@computed_region_p6sk_2acq":"26",":@computed_region_gxvr_9jxz":"44"}\n,{"primary_key":"20220632390_11","incident_number":"20220632390","report_type":"W","report_type_description":"WITNESS","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2022-10-10T16:49:00.000","incident_reported":"2022-10-10T16:49:00.000","incident_location":"309 309","latitude":"36.072","longitude":"-86.582","zip_code":"37013","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"740","offense_description":"POLICE INQUIRY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.582,36.072]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7":"1",":@computed_region_p6sk_2acq":"33",":@computed_region_gxvr_9jxz":"15"}\n,{"primary_key":"20220632346_11","incident_number":"20220632346","report_type":"W","report_type_description":"WITNESS","incident_status_code":"O","incident_status_description":"OPEN","investigation_status":"Open","incident_occurred":"2022-10-10T05:30:00.000","incident_reported":"2022-10-10T16:28:00.000","incident_location":"QUAIL VALLEY RD","latitude":"36.14","longitude":"-86.64","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"290","offense_description":"DAMAGE PROP - PRIVATE","weapon_primary":"07","weapon_description":"CLUB","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.64,36.14]},":@computed_region_wvby_4s8j":"1",":@computed_region_3aw5_2wv7": ...

# %%
res = response.json()
res
# Out:
# [{'primary_key': '20220641257_11',
#   'incident_number': '20220641257',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-14T16:00:00.000',
#   'incident_reported': '2022-10-14T16:01:00.000',
#   'incident_location': '4343 4343',
#   'latitude': '36.207',
#   'longitude': '-86.612',
#   'zip_code': '37076',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.612, 36.207]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '27',
#   ':@computed_region_gxvr_9jxz': '44'},
#  {'primary_key': '20220641203_11',
#   'incident_number': '20220641203',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-14T15:31:00.000',
#   'incident_reported': '2022-10-14T15:31:00.000',
#   'incident_location': '5800 5800',
#   'latitude': '36.183',
#   'longitude': '-86.588',
#   'zip_code': '37076',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.588, 36.183]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '26',
#   ':@computed_region_gxvr_9jxz': '44'},
#  {'primary_key': '20220632390_11',
#   'incident_number': '20220632390',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-10T16:49:00.000',
#   'incident_reported': '2022-10-10T16:49:00.000',
#   'incident_location': '309 309',
#   'latitude': '36.072',
#   'longitude': '-86.582',
#   'zip_code': '37013',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.582, 36.072]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220632346_11',
#   'incident_number': '20220632346',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-10T05:30:00.000',
#   'incident_reported': '2022-10-10T16:28:00.000',
#   'incident_location': 'QUAIL VALLEY RD',
#   'latitude': '36.14',
#   'longitude': '-86.64',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.14]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'primary_key': '20220631992_11',
#   'incident_number': '20220631992',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-09T21:00:00.000',
#   'incident_reported': '2022-10-10T13:28:00.000',
#   'incident_location': 'CLEARLAKE DR',
#   'latitude': '36.05',
#   'longitude': '-86.6',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6, 36.05]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '33',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220529601_11',
#   'incident_number': '20220529601',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T17:30:00.000',
#   'incident_reported': '2022-10-20T18:40:00.000',
#   'incident_location': 'MURFREESBORO',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220529560_11',
#   'incident_number': '20220529560',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T17:49:00.000',
#   'incident_reported': '2022-10-20T18:58:00.000',
#   'incident_location': '225 225',
#   'latitude': '36.094',
#   'longitude': '-86.655',
#   'zip_code': '37217',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.655, 36.094]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '22',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'primary_key': '20220529484_11',
#   'incident_number': '20220529484',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T16:40:00.000',
#   'incident_reported': '2022-10-20T16:58:00.000',
#   'incident_location': '3215 3215',
#   'zip_code': '37207',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529453_11',
#   'incident_number': '20220529453',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T16:45:00.000',
#   'incident_reported': '2022-10-20T17:15:00.000',
#   'incident_location': '522 522',
#   'latitude': '36.168',
#   'longitude': '-86.76',
#   'zip_code': '37206',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.168]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '4'},
#  {'primary_key': '20220529401_11',
#   'incident_number': '20220529401',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T14:15:00.000',
#   'incident_reported': '2022-10-20T16:17:00.000',
#   'incident_location': '422 422',
#   'latitude': '36.089',
#   'longitude': '-86.715',
#   'zip_code': '37211',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.715, 36.089]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '12',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220529396_11',
#   'incident_number': '20220529396',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T11:00:00.000',
#   'incident_reported': '2022-10-20T16:28:00.000',
#   'incident_location': '321 321',
#   'zip_code': '37115',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529365_11',
#   'incident_number': '20220529365',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T15:00:00.000',
#   'incident_reported': '2022-10-20T15:31:00.000',
#   'incident_location': '2715 2715',
#   'zip_code': '37218',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT'},
#  {'primary_key': '20220529280_11',
#   'incident_number': '20220529280',
#   'report_type': 'T',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-18T13:00:00.000',
#   'incident_reported': '2022-10-20T14:36:00.000',
#   'incident_location': '5050 5050',
#   'latitude': '36.059',
#   'longitude': '-86.672',
#   'zip_code': '37013',
#   'location_code': '52',
#   'location_description': 'School-College/University',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.672, 36.059]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220529263_11',
#   'incident_number': '20220529263',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T06:26:00.000',
#   'incident_reported': '2022-10-20T14:27:00.000',
#   'incident_location': 'HAMILTON RD',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529262_11',
#   'incident_number': '20220529262',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-16T00:00:00.000',
#   'incident_reported': '2022-10-20T14:42:00.000',
#   'incident_location': 'ATHENS WAY',
#   'latitude': '36.2',
#   'longitude': '-86.8',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.2]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '21'},
#  {'primary_key': '20220529261_11',
#   'incident_number': '20220529261',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-14T13:00:00.000',
#   'incident_reported': '2022-10-20T14:28:00.000',
#   'incident_location': 'ANDERSON',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220529260_11',
#   'incident_number': '20220529260',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T10:00:00.000',
#   'incident_reported': '2022-10-20T13:29:00.000',
#   'incident_location': 'JOSEPH AV',
#   'latitude': '36.18',
#   'longitude': '-86.77',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $1,000 OR >  BUT < $10,000',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.18]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '13',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'primary_key': '20220529243_11',
#   'incident_number': '20220529243',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T22:00:00.000',
#   'incident_reported': '2022-10-20T14:00:00.000',
#   'incident_location': 'CHURCH',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY - MOTOR VEHICLE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220529202_11',
#   'incident_number': '20220529202',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-09-22T14:00:00.000',
#   'incident_reported': '2022-10-20T13:35:00.000',
#   'incident_location': '1525 1525',
#   'latitude': '36.155',
#   'longitude': '-86.791',
#   'zip_code': '37203',
#   'location_code': '41',
#   'location_description': 'Auto Dealership New/Used',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.791, 36.155]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220529189_11',
#   'incident_number': '20220529189',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T00:01:00.000',
#   'incident_reported': '2022-10-20T13:37:00.000',
#   'incident_location': '11TH N AV',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529159_11',
#   'incident_number': '20220529159',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T11:24:00.000',
#   'incident_reported': '2022-10-20T14:18:00.000',
#   'incident_location': 'PLUS PARK',
#   'location_code': '52',
#   'location_description': 'School-College/University',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220529156_11',
#   'incident_number': '20220529156',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T01:30:00.000',
#   'incident_reported': '2022-10-20T13:00:00.000',
#   'incident_location': 'CAHAL AV',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $1,000 OR >  BUT < $10,000',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220529154_11',
#   'incident_number': '20220529154',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T21:00:00.000',
#   'incident_reported': '2022-10-20T12:59:00.000',
#   'incident_location': 'XAVIER DR',
#   'latitude': '36.07',
#   'longitude': '-86.67',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.67, 36.07]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '22',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220529153_11',
#   'incident_number': '20220529153',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T09:00:00.000',
#   'incident_reported': '2022-10-20T13:27:00.000',
#   'incident_location': 'WOODYCREST AV',
#   'latitude': '36.13',
#   'longitude': '-86.75',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.75, 36.13]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '18',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'primary_key': '20220529124_11',
#   'incident_number': '20220529124',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T12:37:00.000',
#   'incident_reported': '2022-10-20T15:13:00.000',
#   'incident_location': '5771 5771',
#   'latitude': '36.045',
#   'longitude': '-86.714',
#   'zip_code': '37211',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.714, 36.045]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '5',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220529123_11',
#   'incident_number': '20220529123',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-05-01T09:00:00.000',
#   'incident_reported': '2022-10-20T12:49:00.000',
#   'incident_location': 'GALLATIN PKE',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529109_21',
#   'incident_number': '20220529109',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T16:00:00.000',
#   'incident_reported': '2022-10-20T13:28:00.000',
#   'incident_location': 'NOLENSVILLE PKE',
#   'latitude': '36.06',
#   'longitude': '-86.72',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '2',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.06]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220529109_11',
#   'incident_number': '20220529109',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T16:00:00.000',
#   'incident_reported': '2022-10-20T13:28:00.000',
#   'incident_location': 'NOLENSVILLE PKE',
#   'latitude': '36.06',
#   'longitude': '-86.72',
#   'location_code': '74',
#   'location_description': 'LOCKER ROOM',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.06]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220529106_11',
#   'incident_number': '20220529106',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T12:36:00.000',
#   'incident_reported': '2022-10-20T12:36:00.000',
#   'incident_location': '2101 2101',
#   'zip_code': '37115',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220529082_11',
#   'incident_number': '20220529082',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-05-01T09:00:00.000',
#   'incident_reported': '2022-10-20T12:40:00.000',
#   'incident_location': 'ANDERSON LN',
#   'latitude': '36.27',
#   'longitude': '-86.71',
#   'location_code': '41',
#   'location_description': 'Auto Dealership New/Used',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.71, 36.27]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '4',
#   ':@computed_region_gxvr_9jxz': '12'},
#  {'primary_key': '20220529073_11',
#   'incident_number': '20220529073',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-16T19:30:00.000',
#   'incident_reported': '2022-10-20T12:27:00.000',
#   'incident_location': 'OLD HICKORY BLVD',
#   'latitude': '36.24',
#   'longitude': '-86.64',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $1,000 OR >  BUT < $10,000',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.24]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '27',
#   ':@computed_region_gxvr_9jxz': '26'},
#  {'primary_key': '20220529021_11',
#   'incident_number': '20220529021',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-02-19T18:30:00.000',
#   'incident_reported': '2022-10-20T11:26:00.000',
#   'incident_location': 'BATE AV',
#   'latitude': '36.13',
#   'longitude': '-86.79',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.79, 36.13]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '19',
#   ':@computed_region_gxvr_9jxz': '36'},
#  {'primary_key': '20220529019_11',
#   'incident_number': '20220529019',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T16:00:00.000',
#   'incident_reported': '2022-10-20T11:24:00.000',
#   'incident_location': 'DONELSON PKE',
#   'location_code': '6',
#   'location_description': 'CONSTRUCTION SITE',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220528997_11',
#   'incident_number': '20220528997',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-18T21:20:00.000',
#   'incident_reported': '2022-10-20T11:55:00.000',
#   'incident_location': 'MICHIGAN AV',
#   'latitude': '36.16',
#   'longitude': '-86.84',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'LARCENY - (FREE TEXT)',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.84, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'primary_key': '20220528990_11',
#   'incident_number': '20220528990',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-09-27T11:21:00.000',
#   'incident_reported': '2022-10-20T11:21:00.000',
#   'incident_location': '664 664',
#   'latitude': '36.084',
#   'longitude': '-86.615',
#   'zip_code': '37217',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.615, 36.084]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'primary_key': '20220528978_11',
#   'incident_number': '20220528978',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-08-31T11:41:00.000',
#   'incident_reported': '2022-10-20T11:41:00.000',
#   'incident_location': 'POWELL AVE',
#   'latitude': '36.11',
#   'longitude': '-86.77',
#   'location_code': '41',
#   'location_description': 'Auto Dealership New/Used',
#   'offense_number': '1',
#   'offense_nibrs': '26A',
#   'offense_description': 'FRAUD - SWINDLE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'primary_key': '20220528934_11',
#   'incident_number': '20220528934',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-20T10:39:00.000',
#   'incident_reported': '2022-10-20T10:39:00.000',
#   'incident_location': '628 628',
#   'zip_code': '37207',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220528932_11',
#   'incident_number': '20220528932',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-19T11:35:00.000',
#   'incident_reported': '2022-10-20T10:45:00.000',
#   'incident_location': 'CHARLES E DAVIS BLVD',
#   'latitude': '36.15',
#   'longitude': '-86.76',
#   'location_code': '72',
#   'location_description': "DOCTORS'S OFFICE",
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'Assault, health care provider - Fear of Bodily Injury',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.15]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'primary_key': '20220528908_11',
#   'incident_number': '20220528908',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-04-30T10:00:00.000',
#   'incident_reported': '2022-10-20T10:17:00.000',
#   'incident_location': 'CEDAR POINTE PKWY',
#   'latitude': '36.05',
#   'longitude': '-86.66',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.66, 36.05]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220528892_11',
#   'incident_number': '20220528892',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-06T14:30:00.000',
#   'incident_reported': '2022-10-20T10:19:00.000',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'CREDIT CARD, FRAUDULENT USE - $1,000 OR LESS',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'},
#  {'primary_key': '20220528890_11',
#   'incident_number': '20220528890',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-06T14:30:00.000',
#   'incident_reported': '2022-10-20T10:15:00.000',
#   'incident_location': 'HILLSBORO PKE',
#   'latitude': '36.11',
#   'longitude': '-86.82',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'CREDIT CARD, FRAUDULENT USE - $1,000 OR LESS',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.82, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'primary_key': '20220528888_11',
#   'incident_number': '20220528888',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-06T09:59:00.000',
#   'incident_reported': '2022-10-20T10:06:00.000',
#   'incident_location': '3150 3150',
#   'latitude': '36.299',
#   'longitude': '-86.7',
#   'zip_code': '37214',
#   'location_code': '53',
#   'location_description': 'School-Elementary/Secondary',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.299]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '17',
#   ':@computed_region_gxvr_9jxz': '41'},
#  {'primary_key': '20220528863_11',
#   'incident_number': '20220528863',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-06T14:31:00.000',
#   'incident_reported': '2022-10-20T09:55:00.000',
#   'incident_location': 'NOLENSVILLE PKE',
#   'latitude': '36.07',
#   'longitude': '-86.72',
#   'location_code': '71',
#   'location_description': 'PHARMACY',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'CREDIT CARD, FRAUDULENT USE - $1,000 OR LESS',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.07]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '28',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220528861_11',
#   'incident_number': '20220528861',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-06T14:31:00.000',
#   'incident_reported': '2022-10-20T09:50:00.000',
#   'incident_location': 'EDMONDSON PKE',
#   'latitude': '36.04',
#   'longitude': '-86.74',
#   'location_code': '12',
#   'location_description': 'GROCERY, SUPERMARKET',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'CREDIT CARD, FRAUDULENT USE - >$1,000 BUT < $2,500',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.74, 36.04]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220528847_11',
#   'incident_number': '20220528847',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-19T09:59:00.000',
#   'incident_reported': '2022-10-20T11:55:00.000',
#   'incident_location': '3150 3150',
#   'latitude': '36.299',
#   'longitude': '-86.7',
#   'zip_code': '37214',
#   'location_code': '53',
#   'location_description': 'School-Elementary/Secondary',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.299]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '17',
#   ':@computed_region_gxvr_9jxz': '41'},
#  {'primary_key': '20220528842_11',
#   'incident_number': '20220528842',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-20T09:00:00.000',
#   'incident_reported': '2022-10-20T13:07:00.000',
#   'incident_location': 'TOWNES DR',
#   'latitude': '36.05',
#   'longitude': '-86.7',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'A',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.05]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '29',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220528831_11',
#   'incident_number': '20220528831',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-08T06:30:00.000',
#   'incident_reported': '2022-10-20T09:46:00.000',
#   'incident_location': 'HARDING PL',
#   'latitude': '36.09',
#   'longitude': '-86.7',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '26B',
#   'offense_description': 'CREDIT CARD, FRAUDULENT USE - $1,000 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.09]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'primary_key': '20220528830_11',
#   'incident_number': '20220528830',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-08T06:30:00.000',
#   'incident_reported': '2022-10-20T09:40:00.000',
#   'incident_location': 'LEBANON PKE',
#   'latitude': '36.17',
#   'longitude': '-86.66',
#   'location_code': '7',
#   'location_description': 'CONVENIENCE STORE',
# ...
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220519759_21',
#   'incident_number': '20220519759',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-09-21T00:33:00.000',
#   'incident_reported': '2022-10-15T14:37:00.000',
#   'incident_location': '24TH',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '2',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220519759_12',
#   'incident_number': '20220519759',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-09-21T00:33:00.000',
#   'incident_reported': '2022-10-15T14:37:00.000',
#   'incident_location': '24TH',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON - FIREARM OR CLUB',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY'},
#  {'primary_key': '20220519754_11',
#   'incident_number': '20220519754',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-15T13:45:00.000',
#   'incident_reported': '2022-10-15T14:02:00.000',
#   'incident_location': '1725 1725',
#   'zip_code': '37208',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'NON RESIDENT'},
#  {'primary_key': '20220519751_11',
#   'incident_number': '20220519751',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-15T13:43:00.000',
#   'incident_reported': '2022-10-15T14:25:00.000',
#   'incident_location': '715 715',
#   'latitude': '36.174',
#   'longitude': '-86.759',
#   'zip_code': '37206',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.174]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '4'},
#  {'primary_key': '20220519749_21',
#   'incident_number': '20220519749',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-14T18:40:00.000',
#   'incident_reported': '2022-10-15T14:15:00.000',
#   'incident_location': 'POWELL AV',
#   'latitude': '36.11',
#   'longitude': '-86.77',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '2',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '06',
#   'weapon_description': 'LETHAL/CUTTING INSTRUMENT',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'primary_key': '20220519749_11',
#   'incident_number': '20220519749',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-14T18:40:00.000',
#   'incident_reported': '2022-10-15T14:15:00.000',
#   'incident_location': 'POWELL AV',
#   'latitude': '36.11',
#   'longitude': '-86.77',
#   'location_code': '26',
#   'location_description': 'SPECIALTY STORE',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - BUSINESS',
#   'weapon_primary': '06',
#   'weapon_description': 'LETHAL/CUTTING INSTRUMENT',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.11]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'primary_key': '20220519743_11',
#   'incident_number': '20220519743',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T13:00:00.000',
#   'incident_reported': '2022-10-15T14:12:00.000',
#   'incident_location': 'BELL RD',
#   'latitude': '36.06',
#   'longitude': '-86.64',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.06]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220519739_11',
#   'incident_number': '20220519739',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-14T11:30:00.000',
#   'incident_reported': '2022-10-15T14:18:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220519737_11',
#   'incident_number': '20220519737',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-15T12:00:00.000',
#   'incident_reported': '2022-10-15T14:10:00.000',
#   'incident_location': '136 136',
#   'latitude': '36.098',
#   'longitude': '-86.64',
#   'zip_code': '37217',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.098]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'primary_key': '20220519729_11',
#   'incident_number': '20220519729',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-10-15T14:28:00.000',
#   'incident_reported': '2022-10-15T14:28:00.000',
#   'incident_location': '5000 5000',
#   'latitude': '36.045',
#   'longitude': '-86.609',
#   'zip_code': '37013',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.609, 36.045]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220519726_13',
#   'incident_number': '20220519726',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T12:13:00.000',
#   'incident_reported': '2022-10-15T15:13:00.000',
#   'incident_location': 'HICKORY HIGHLANDS DR',
#   'latitude': '36.06',
#   'longitude': '-86.64',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '3',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.06]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220519726_11',
#   'incident_number': '20220519726',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T12:13:00.000',
#   'incident_reported': '2022-10-15T15:13:00.000',
#   'incident_location': 'HICKORY HIGHLANDS DR',
#   'latitude': '36.06',
#   'longitude': '-86.64',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.06]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'primary_key': '20220519718_11',
#   'incident_number': '20220519718',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T03:00:00.000',
#   'incident_reported': '2022-10-15T13:36:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '23A',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'primary_key': '20220519715_11',
#   'incident_number': '20220519715',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-15T13:05:00.000',
#   'incident_reported': '2022-10-15T14:17:00.000',
#   'incident_location': 'LEBANON PKE',
#   'latitude': '36.2',
#   'longitude': '-86.62',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'ASSAULT, DOMESTIC, BODILY INJURY 3RD OR MORE - ENHANCED',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.62, 36.2]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '27',
#   ':@computed_region_gxvr_9jxz': '44'},
#  {'primary_key': '20220519709_11',
#   'incident_number': '20220519709',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-10-14T16:30:00.000',
#   'incident_reported': '2022-10-15T13:57:00.000',
#   'incident_location': '2ND N AV',
#   'location_code': '6',
#   'location_description': 'CONSTRUCTION SITE',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'LARCENY - (FREE TEXT)',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS'}]

# %%
type(res)
# Out:
# list

# %%
pd.DataFrame(res)
# Out:
#         primary_key incident_number report_type report_type_description  \
# 0    20220641257_11     20220641257           W                 WITNESS
# 1    20220641203_11     20220641203           W                 WITNESS
# 2    20220632390_11     20220632390           W                 WITNESS
# 3    20220632346_11     20220632346           W                 WITNESS
# 4    20220631992_11     20220631992           W                 WITNESS
# ..              ...             ...         ...                     ...
# 995  20220519726_13     20220519726           D              DISPATCHED
# 996  20220519726_11     20220519726           D              DISPATCHED
# 997  20220519718_11     20220519718           D              DISPATCHED
# 998  20220519715_11     20220519715           D              DISPATCHED
# 999  20220519709_11     20220519709           T                     NaN
#
#     incident_status_code incident_status_description investigation_status  \
# 0                      U                   UNFOUNDED               Closed
# 1                      U                   UNFOUNDED               Closed
# 2                      U                   UNFOUNDED               Closed
# 3                      O                        OPEN                 Open
# 4                      O                        OPEN                 Open
# ..                   ...                         ...                  ...
# 995                    O                        OPEN                 Open
# 996                    O                        OPEN                 Open
# 997                    O                        OPEN                 Open
# 998                    O                        OPEN                 Open
# 999                    O                        OPEN                 Open
#
#            incident_occurred        incident_reported     incident_location  \
# 0    2022-10-14T16:00:00.000  2022-10-14T16:01:00.000             4343 4343
# 1    2022-10-14T15:31:00.000  2022-10-14T15:31:00.000             5800 5800
# 2    2022-10-10T16:49:00.000  2022-10-10T16:49:00.000               309 309
# 3    2022-10-10T05:30:00.000  2022-10-10T16:28:00.000       QUAIL VALLEY RD
# 4    2022-10-09T21:00:00.000  2022-10-10T13:28:00.000          CLEARLAKE DR
# ..                       ...                      ...                   ...
# 995  2022-10-15T12:13:00.000  2022-10-15T15:13:00.000  HICKORY HIGHLANDS DR
# 996  2022-10-15T12:13:00.000  2022-10-15T15:13:00.000  HICKORY HIGHLANDS DR
# 997  2022-10-15T03:00:00.000  2022-10-15T13:36:00.000              BROADWAY
# 998  2022-10-15T13:05:00.000  2022-10-15T14:17:00.000           LEBANON PKE
# 999  2022-10-14T16:30:00.000  2022-10-15T13:57:00.000              2ND N AV
#
#      ...        victim_description victim_gender victim_race victim_ethnicity  \
# 0    ...  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 1    ...  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 2    ...  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 3    ...  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4    ...  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# ..   ...                       ...           ...         ...              ...
# 995  ...  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 996  ...  INDIVIDUAL (18 AND OVER)             M           B     Non-Hispanic
# 997  ...  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 998  ...  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 999  ...                  BUSINESS           NaN         NaN              NaN
#
#     victim_county_resident                                    mapped_location  \
# 0                 RESIDENT  {'type': 'Point', 'coordinates': [-86.612, 36....
# 1                 RESIDENT  {'type': 'Point', 'coordinates': [-86.588, 36....
# 2                 RESIDENT  {'type': 'Point', 'coordinates': [-86.582, 36....
# 3                 RESIDENT  {'type': 'Point', 'coordinates': [-86.64, 36.14]}
# 4             NON RESIDENT   {'type': 'Point', 'coordinates': [-86.6, 36.05]}
# ..                     ...                                                ...
# 995           NON RESIDENT  {'type': 'Point', 'coordinates': [-86.64, 36.06]}
# 996           NON RESIDENT  {'type': 'Point', 'coordinates': [-86.64, 36.06]}
# 997           NON RESIDENT  {'type': 'Point', 'coordinates': [-86.78, 36.16]}
# 998               RESIDENT   {'type': 'Point', 'coordinates': [-86.62, 36.2]}
# 999                    NaN                                                NaN
#
#     :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                             1                           2
# 1                             1                           2
# 2                             1                           1
# 3                             1                           2
# 4                             1                           2
# ..                          ...                         ...
# 995                           1                           1
# 996                           1                           1
# 997                           1                           1
# 998                           1                           2
# 999                         NaN                         NaN
#
#     :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz
# 0                            27                          44
# 1                            26                          44
# 2                            33                          15
# 3                             6                          38
# 4                            33                          15
# ..                          ...                         ...
# 995                          30                          15
# 996                          30                          15
# 997                          20                          40
# 998                          27                          44
# 999                         NaN                         NaN
#
# [1000 rows x 33 columns]

# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Analyzing Aggravated Burglaries in Davidson County

# %% [markdown]
# ### Part 1 - Data Gathering using APIs
#
# 1. A dataset containing details about Metro Nashville Police Department reported incidents is available at https://data.nashville.gov/Police/Metro-Nashville-Police-Department-Incidents/2u6v-ujjs. Make use of the API to find all aggravated burglary incidents () that were reported during the nine month period from January 1, 2022 through September 30, 2022. (**Hint:** Check out the [API Docs](https://dev.socrata.com/foundry/data.nashville.gov/2u6v-ujjs) to see how to narrow down the response to just the desired results).

# %% [markdown]
# **Aggrivated Burglary** - TIBRS Data Collection Manual states that TN uses NIBRS for coding offenses under TN Code Annotated 39-14-403.  The following NIBRS codes are used for aggrivated burglary in Tennessee
# - Burglary - 220
# - Assualt - 13A
# - Robery - 120
# - Weapon Law Violation - 520

# %%
#Setup API Access
with open('app_token.json') as fi:
    credentials = json.load(fi)
api_key = credentials['token']

#########
#delete me
###########

# %% [markdown]
# API Fields
# - `incident_occurred` - Date and time the incident occurred
#     - $where=date between `start` and `stop`
#     - ISO8601 Times (GMT-5)
#         - **1.1.22** `2022-01-01T00:00:00-0500`
#         - **9.30.22** `2022-09-30T23:59:59-0500`
# - date = `'date between '2015-01-10T12:00:00' and '2015-01-10T14:00:00'`

# %%
#use 220 for now.  More filters are better.
Agg_Bur = ['220', '13A', '120', '520']
dates = ("'2022-01-01T00:00:00'", "'2022-09-30T23:59:59'")
#HOWTOFINDINCIDENTOCCURRED = f'incident_occurred between''2015-01-10T12:00:00'' and ''2015-01-10T14:00:00''
#originaldates = f'$where=incident_occurred between '+start+' and '+stop
print(dates[0])
# Out:
# '2022-01-01T00:00:00'

# %%
# By default, it's only going to give you 100 Rows back
# https://dev.socrata.com/docs/paging.html#2.1 - up the limit of responses
endpoint = 'https://data.nashville.gov/resource/2u6v-ujjs.json'
params = {
    '$where': f'incident_occurred between '+dates[0]+' and '+dates[1],
    #offense_nibrs#
    '$$app_token': api_key
}
response = requests.get(endpoint)
###################Original 
#params = {'incident_occurred': dates}
#response = requests.get(endpoint, params = params)
#'offense_nibrs' : Agg_Bur,
#'$$app_token': app_token

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
res = response.json()
res
# Out:
# [{'primary_key': '20220002526_11',
#   'incident_number': '20220002526',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-03T00:50:00.000',
#   'incident_location': '4TH AVE N',
#   'latitude': '36.17',
#   'longitude': '-86.79',
#   'rpa': '4235',
#   'zone': '413',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.79, 36.17]}},
#  {'primary_key': '20220047605_11',
#   'incident_number': '20220047605',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-02-01T10:33:00.000',
#   'incident_location': '7716 7716',
#   'zip_code': '37080',
#   'location_code': '10',
#   'location_description': 'FIELD, WOODS',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT'},
#  {'primary_key': '20220046961_11',
#   'incident_number': '20220046961',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-02-01T02:52:00.000',
#   'incident_location': '2209 2209',
#   'latitude': '36.106',
#   'longitude': '-86.82',
#   'zip_code': '37215',
#   'rpa': '6113',
#   'zone': '113',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.82, 36.106]}},
#  {'primary_key': '20220056911_11',
#   'incident_number': '20220056911',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-02-07T07:52:00.000',
#   'incident_location': 'HOBSON PIKE',
#   'latitude': '36.05',
#   'longitude': '-86.6',
#   'rpa': '8971',
#   'zone': '337',
#   'location_code': '10',
#   'location_description': 'FIELD, WOODS',
#   'offense_number': '1',
#   'offense_nibrs': '90C',
#   'offense_description': 'DISORDERLY CONDUCT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6, 36.05]}},
#  {'primary_key': '20220000685_11',
#   'incident_number': '20220000685',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T13:43:00.000',
#   'incident_location': 'SHELBY AVE',
#   'latitude': '36.17',
#   'longitude': '-86.74',
#   'rpa': '1223',
#   'zone': '213',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.74, 36.17]}},
#  {'primary_key': '20220000741_11',
#   'incident_number': '20220000741',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T14:04:00.000',
#   'incident_location': 'ROSA L PARKS BLVD',
#   'latitude': '36.19',
#   'longitude': '-86.8',
#   'rpa': '4445',
#   'zone': '611',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.19]}},
#  {'primary_key': '20220000938_11',
#   'incident_number': '20220000938',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T17:50:00.000',
#   'incident_location': 'N 5TH ST',
#   'latitude': '36.19',
#   'longitude': '-86.76',
#   'rpa': '1907',
#   'zone': '221',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '05',
#   'weapon_description': 'OTHER FIREARM',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.19]}},
#  {'primary_key': '20220000252_22',
#   'incident_number': '20220000252',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T05:04:00.000',
#   'incident_location': 'WALLACE RD',
#   'latitude': '36.08',
#   'longitude': '-86.72',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '03',
#   'weapon_description': 'SHOTGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.08]}},
#  {'primary_key': '20220001729_11',
#   'incident_number': '20220001729',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-02T07:36:00.000',
#   'incident_location': '16TH AVE N',
#   'latitude': '36.18',
#   'longitude': '-86.81',
#   'rpa': '4413',
#   'zone': '611',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.18]}},
#  {'primary_key': '20220000615_11',
#   'incident_number': '20220000615',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T11:34:00.000',
#   'incident_location': '1515 1515',
#   'latitude': '36.202',
#   'longitude': '-86.729',
#   'zip_code': '37216',
#   'rpa': '1413',
#   'zone': '215',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.729, 36.202]}},
#  {'primary_key': '20220001885_11',
#   'incident_number': '20220001885',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-02T12:04:00.000',
#   'incident_location': 'RUDY CIR',
#   'latitude': '36.22',
#   'longitude': '-86.7',
#   'rpa': '9213',
#   'zone': '515',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.22]}},
#  {'primary_key': '20220004678_11',
#   'incident_number': '20220004678',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-04T12:53:00.000',
#   'incident_location': 'CLARKSVILLE PIKE',
#   'latitude': '36.18',
#   'longitude': '-86.81',
#   'rpa': '4417',
#   'zone': '621',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.18]}},
#  {'primary_key': '20220000672_11',
#   'incident_number': '20220000672',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T12:54:00.000',
#   'incident_location': 'BURNS ST',
#   'latitude': '36.2',
#   'longitude': '-86.73',
#   'rpa': '1405',
#   'zone': '215',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.73, 36.2]}},
#  {'primary_key': '20220000415_11',
#   'incident_number': '20220000415',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T08:30:00.000',
#   'incident_location': 'MERIDIAN ST',
#   'latitude': '36.2',
#   'longitude': '-86.77',
#   'rpa': '1859',
#   'zone': '221',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '15',
#   'weapon_description': 'OTHER',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.2]}},
#  {'primary_key': '20220000252_11',
#   'incident_number': '20220000252',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T05:04:00.000',
#   'incident_location': 'WALLACE RD',
#   'latitude': '36.08',
#   'longitude': '-86.72',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'INTENTIONAL AGGRAVATED ASSAULT',
#   'weapon_primary': '03',
#   'weapon_description': 'SHOTGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.08]}},
#  {'primary_key': '20220000485_11',
#   'incident_number': '20220000485',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T08:41:00.000',
#   'incident_location': 'PUBLIC SQ',
#   'latitude': '36.17',
#   'longitude': '-86.78',
#   'location_code': '19',
#   'location_description': 'PARK',
#   'offense_number': '1',
#   'offense_nibrs': '120',
#   'offense_description': 'ROBBERY',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.17]}},
#  {'primary_key': '20220009217_11',
#   'incident_number': '20220009217',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-07T13:07:00.000',
#   'incident_location': '4TH AVE N',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]}},
#  {'primary_key': '20220004899_11',
#   'incident_number': '20220004899',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-04T15:24:00.000',
#   'incident_location': 'COWAN ST',
#   'latitude': '36.17',
#   'longitude': '-86.78',
#   'rpa': '1989',
#   'zone': '413',
#   'location_code': '4',
#   'location_description': 'CHURCH, SYNAGOGUE, TEMPLE',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGL - FORCED ENTRY-NONRESID',
#   'weapon_primary': '15',
#   'weapon_description': 'OTHER',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.17]}},
#  {'primary_key': '20220013496_11',
#   'incident_number': '20220013496',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-10T17:51:00.000',
#   'incident_location': 'GRIZZARD AVE',
#   'latitude': '36.21',
#   'longitude': '-86.77',
#   'rpa': '1829',
#   'zone': '223',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.21]}},
#  {'primary_key': '20220010447_11',
#   'incident_number': '20220010447',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-08T14:09:00.000',
#   'incident_location': 'REVELS DR',
#   'latitude': '36.22',
#   'longitude': '-86.8',
#   'rpa': '3047',
#   'zone': '633',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '05',
#   'weapon_description': 'OTHER FIREARM',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.22]}},
#  {'primary_key': '20220017978_11',
#   'incident_number': '20220017978',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-13T11:49:00.000',
#   'incident_location': 'DICKERSON PIKE',
#   'latitude': '36.26',
#   'longitude': '-86.76',
#   'rpa': '2019',
#   'zone': '723',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.26]}},
#  {'primary_key': '20220013070_21',
#   'incident_number': '20220013070',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-10T12:36:00.000',
#   'incident_location': 'N 8TH ST',
#   'latitude': '36.18',
#   'longitude': '-86.76',
#   'rpa': '1999',
#   'zone': '227',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '2',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.18]}},
#  {'primary_key': '20220013070_11',
#   'incident_number': '20220013070',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-10T12:36:00.000',
#   'incident_location': 'N 8TH ST',
#   'latitude': '36.18',
#   'longitude': '-86.76',
#   'rpa': '1999',
#   'zone': '227',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $500 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.18]}},
#  {'primary_key': '20220075027_11',
#   'incident_number': '20220075027',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-02-17T23:44:00.000',
#   'incident_location': 'LOVELL ST',
#   'latitude': '36.27',
#   'longitude': '-86.71',
#   'rpa': '1707',
#   'zone': '715',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGLARY- AGGRAVATED',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.71, 36.27]}},
#  {'primary_key': '20220001114_11',
#   'incident_number': '20220001114',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-01T20:35:00.000',
#   'incident_location': '3353 3353',
#   'latitude': '36.138',
#   'longitude': '-86.819',
#   'zip_code': '37212',
#   'rpa': '5819',
#   'zone': '813',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGLARY- AGGRAVATED',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.819, 36.138]}},
#  {'primary_key': '20220203068_11',
#   'incident_number': '20220203068',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-04-26T23:14:00.000',
#   'incident_location': 'SUNSAIL DR',
#   'latitude': '36.07',
#   'longitude': '-86.58',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '720',
#   'offense_description': 'HARRASSMENT (NUISANCE)',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.58, 36.07]}},
#  {'primary_key': '20220297184_11',
#   'incident_number': '20220297184',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-06-16T19:10:00.000',
#   'incident_location': '297 297',
#   'latitude': '36.092',
#   'longitude': '-86.733',
#   'zip_code': '37211',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.733, 36.092]}},
#  {'primary_key': '20220272901_11',
#   'incident_number': '20220272901',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-06-02T19:11:00.000',
#   'incident_location': 'JACKSON DOWNS BLVD',
#   'latitude': '36.18',
#   'longitude': '-86.64',
#   'location_code': '21',
#   'location_description': 'RENTAL STORAGE FACILITY',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGL - NO FORCED ENTRY-NONRESID',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.18]}},
#  {'primary_key': '20220015937_11',
#   'incident_number': '20220015937',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-12T09:46:00.000',
#   'incident_location': 'STEWARTS LN',
#   'latitude': '36.2',
#   'longitude': '-86.86',
#   'rpa': '3133',
#   'zone': '625',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.86, 36.2]}},
#  {'primary_key': '20220015937_14',
#   'incident_number': '20220015937',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-12T09:46:00.000',
#   'incident_location': 'STEWARTS LN',
#   'latitude': '36.2',
#   'longitude': '-86.86',
#   'rpa': '3133',
#   'zone': '625',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '4',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.86, 36.2]}},
#  {'primary_key': '20220028813_11',
#   'incident_number': '20220028813',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-20T13:57:00.000',
#   'incident_location': 'ELLISTON PL',
#   'latitude': '36.15',
#   'longitude': '-86.81',
#   'rpa': '5617',
#   'zone': '813',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.15]}},
#  {'primary_key': '20220015937_13',
#   'incident_number': '20220015937',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-12T09:46:00.000',
#   'incident_location': 'STEWARTS LN',
#   'latitude': '36.2',
#   'longitude': '-86.86',
#   'rpa': '3133',
#   'zone': '625',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.86, 36.2]}},
#  {'primary_key': '20220015937_12',
#   'incident_number': '20220015937',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-01-12T09:46:00.000',
#   'incident_location': 'STEWARTS LN',
#   'latitude': '36.2',
#   'longitude': '-86.86',
#   'rpa': '3133',
#   'zone': '625',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.86, 36.2]}},
#  {'primary_key': '20220101417_11',
#   'incident_number': '20220101417',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-03-05T10:21:00.000',
#   'incident_location': 'AMHERST DR',
#   'latitude': '36.17',
#   'longitude': '-86.7',
#   'rpa': '9219',
#   'zone': '513',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.17]}},
#  {'primary_key': '20220159077_11',
#   'incident_number': '20220159077',
#   'report_type': 'W',
#   'report_type_description': 'WITNESS',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-04-04T12:10:00.000',
#   'incident_location': '534 534',
#   'latitude': '36.272',
#   'longitude': '-86.7',
#   'zip_code': '37115',
#   'rpa': '1727',
#   'zone': '715',
#   'location_code': '28',
#   'location_description': 'OTHER, UNKNOWN',
#   'offense_number': '1',
#   'offense_nibrs': '715',
#   'offense_description': 'FOUND PROPERTY',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'U',
#   'victim_description': 'UNKNOWN',
#   'victim_gender': 'U',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Non-Hispanic',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.272]}},
#  {'primary_key': '20220486008_11',
#   'incident_number': '20220486008',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-09-27T12:57:00.000',
#   'incident_location': 'MADISON SQ',
#   'latitude': '36.26',
#   'longitude': '-86.71',
#   'location_code': '12',
#   'location_description': 'GROCERY, SUPERMARKET',
#   'offense_number': '1',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- $10,000 OR >  BUT  < $60,000',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.71, 36.26]}},
#  {'primary_key': '20220501643_11',
#   'incident_number': '20220501643',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:00:00.000',
#   'incident_reported': '2022-10-05T10:51:00.000',
#   'incident_location': 'CHIMNEYTOP DR',
#   'latitude': '36.04',
#   'longitude': '-86.66',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '370',
#   'offense_description': 'OBSCENE MATERIAL - SELL',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.66, 36.04]}},
#  {'primary_key': '20220000647_11',
#   'incident_number': '20220000647',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:01:00.000',
#   'incident_reported': '2022-01-01T13:49:00.000',
#   'incident_location': 'NOLENSVILLE PIKE',
#   'latitude': '36.07',
#   'longitude': '-86.72',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.07]}},
#  {'primary_key': '20220001059_11',
#   'incident_number': '20220001059',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:01:00.000',
#   'incident_reported': '2022-01-01T20:25:00.000',
#   'incident_location': '1598 1598',
#   'latitude': '36.294',
#   'longitude': '-86.706',
#   'zip_code': '37115',
#   'rpa': '1757',
#   'zone': '727',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.706, 36.294]}},
#  {'primary_key': '20220014868_11',
#   'incident_number': '20220014868',
#   'report_type': 'T',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:01:00.000',
#   'incident_reported': '2022-01-11T12:48:00.000',
#   'incident_location': '221 221',
#   'latitude': '36.162',
#   'longitude': '-86.775',
#   'zip_code': '37201',
#   'rpa': '4093',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'O',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.775, 36.162]}},
#  {'primary_key': '20220087236_11',
#   'incident_number': '20220087236',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:01:00.000',
#   'incident_reported': '2022-02-25T10:47:00.000',
#   'incident_location': 'FOWLER ST',
#   'latitude': '36.26',
#   'longitude': '-86.65',
#   'rpa': '9611',
#   'zone': '527',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.65, 36.26]}},
#  {'primary_key': '20220383517_11',
#   'incident_number': '20220383517',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:01:00.000',
#   'incident_reported': '2022-08-04T12:20:00.000',
#   'incident_location': '1516 1516',
#   'latitude': '36.187',
#   'longitude': '-86.718',
#   'zip_code': '37206',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.718, 36.187]}},
#  {'primary_key': '20220000016_11',
#   'incident_number': '20220000016',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:05:00.000',
#   'incident_reported': '2022-01-01T01:30:00.000',
#   'incident_location': '1317 1317',
#   'latitude': '36.209',
#   'longitude': '-86.724',
#   'zip_code': '37216',
#   'rpa': '1443',
#   'zone': '215',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.724, 36.209]}},
#  {'primary_key': '20220000016_21',
#   'incident_number': '20220000016',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:05:00.000',
#   'incident_reported': '2022-01-01T01:30:00.000',
#   'incident_location': '1317 1317',
#   'latitude': '36.209',
#   'longitude': '-86.724',
#   'zip_code': '37216',
#   'rpa': '1443',
#   'zone': '215',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '2',
#   'offense_nibrs': '35A',
#   'offense_description': 'MARIJUANA - POSSESS',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.724, 36.209]}},
#  {'primary_key': '20220000049_11',
#   'incident_number': '20220000049',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T03:31:00.000',
#   'incident_location': 'RURAL HILL RD',
#   'latitude': '36.08',
#   'longitude': '-86.63',
#   'rpa': '8963',
#   'zone': '535',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '695',
#   'offense_description': 'UNKNOWN DEATH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.08]}},
#  {'primary_key': '20220000443_11',
#   'incident_number': '20220000443',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T09:03:00.000',
#   'incident_location': 'EAGLE VIEW BLVD',
#   'latitude': '36.05',
#   'longitude': '-86.64',
#   'rpa': '8865',
#   'zone': '333',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.64, 36.05]}},
#  {'primary_key': '20220000026_23',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000026_11',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000026_12',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000042_11',
#   'incident_number': '20220000042',
#   'report_type': 'D',
# ...
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.2]}},
#  {'primary_key': '20220003768_12',
#   'incident_number': '20220003768',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T19:40:00.000',
#   'incident_reported': '2022-01-03T20:29:00.000',
#   'incident_location': '110 110',
#   'latitude': '36.281',
#   'longitude': '-86.707',
#   'zip_code': '37115',
#   'rpa': '1717',
#   'zone': '715',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '2',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.707, 36.281]}},
#  {'primary_key': '20220003768_11',
#   'incident_number': '20220003768',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T19:40:00.000',
#   'incident_reported': '2022-01-03T20:29:00.000',
#   'incident_location': '110 110',
#   'latitude': '36.281',
#   'longitude': '-86.707',
#   'zip_code': '37115',
#   'rpa': '1717',
#   'zone': '715',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.707, 36.281]}},
#  {'primary_key': '20220035804_11',
#   'incident_number': '20220035804',
#   'report_type': 'T',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T19:45:00.000',
#   'incident_reported': '2022-01-25T07:22:00.000',
#   'incident_location': '8047 8047',
#   'latitude': '36.022',
#   'longitude': '-86.712',
#   'zip_code': '37013',
#   'rpa': '8759',
#   'zone': '331',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.712, 36.022]}},
#  {'primary_key': '20220003830_11',
#   'incident_number': '20220003830',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T19:54:00.000',
#   'incident_reported': '2022-01-03T20:58:00.000',
#   'incident_location': '198 198',
#   'latitude': '36.07',
#   'longitude': '-86.694',
#   'zip_code': '37211',
#   'location_code': '25',
#   'location_description': 'SERVICE, GAS STATION',
#   'offense_number': '1',
#   'offense_nibrs': '715',
#   'offense_description': 'FOUND PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.694, 36.07]}},
#  {'primary_key': '20220003804_11',
#   'incident_number': '20220003804',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T19:54:00.000',
#   'incident_reported': '2022-01-03T20:50:00.000',
#   'incident_location': 'HAYWOOD LN',
#   'latitude': '36.07',
#   'longitude': '-86.69',
#   'location_code': '25',
#   'location_description': 'SERVICE, GAS STATION',
#   'offense_number': '1',
#   'offense_nibrs': '23C',
#   'offense_description': 'SHOPLIFTING',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.69, 36.07]}},
#  {'primary_key': '20220010228_11',
#   'incident_number': '20220010228',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-21T12:49:00.000',
#   'incident_location': 'MURFREESBORO PIKE',
#   'latitude': '36.07',
#   'longitude': '-86.63',
#   'location_code': '21',
#   'location_description': 'RENTAL STORAGE FACILITY',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGL - FORCED ENTRY-NONRESID',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.07]}},
#  {'primary_key': '20220010228_21',
#   'incident_number': '20220010228',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-21T12:49:00.000',
#   'incident_location': 'MURFREESBORO PIKE',
#   'latitude': '36.07',
#   'longitude': '-86.63',
#   'location_code': '21',
#   'location_description': 'RENTAL STORAGE FACILITY',
#   'offense_number': '2',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - BUSINESS',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.07]}},
#  {'primary_key': '20220003777_11',
#   'incident_number': '20220003777',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-03T21:02:00.000',
#   'incident_location': '3441 3441',
#   'latitude': '36.244',
#   'longitude': '-86.756',
#   'zip_code': '37207',
#   'rpa': '2009',
#   'zone': '723',
#   'location_code': '9',
#   'location_description': 'HOSPITAL',
#   'offense_number': '1',
#   'offense_nibrs': '35A',
#   'offense_description': 'DRUG FREE SCH.ZONE-CONT.SUB.-SCH. IV',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.756, 36.244]}},
#  {'primary_key': '20220004485_11',
#   'incident_number': '20220004485',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-04T09:51:00.000',
#   'incident_location': 'RUFFIAN WAY',
#   'latitude': '36.06',
#   'longitude': '-86.61',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.61, 36.06]}},
#  {'primary_key': '20220003771_11',
#   'incident_number': '20220003771',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-03T21:44:00.000',
#   'incident_location': '549 549',
#   'latitude': '36.222',
#   'longitude': '-86.845',
#   'zip_code': '37218',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '35A',
#   'offense_description': 'MARIJUANA - POSSESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.845, 36.222]}},
#  {'primary_key': '20220003810_21',
#   'incident_number': '20220003810',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-03T22:04:00.000',
#   'incident_location': '3036 3036',
#   'latitude': '36.221',
#   'longitude': '-86.823',
#   'zip_code': '37218',
#   'rpa': '3143',
#   'zone': '625',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '2',
#   'offense_nibrs': '23H',
#   'offense_description': 'THEFT OF PROPERTY- > $500 BUT < $1,000',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.823, 36.221]}},
#  {'primary_key': '20220003810_11',
#   'incident_number': '20220003810',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T20:00:00.000',
#   'incident_reported': '2022-01-03T22:04:00.000',
#   'incident_location': '3036 3036',
#   'latitude': '36.221',
#   'longitude': '-86.823',
#   'zip_code': '37218',
#   'rpa': '3143',
#   'zone': '625',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'INTENTIONAL AGGRAVATED ASSAULT',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.823, 36.221]}},
#  {'primary_key': '20220003772_11',
#   'incident_number': '20220003772',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T20:01:00.000',
#   'incident_reported': '2022-01-03T20:35:00.000',
#   'incident_location': '3458 3458',
#   'latitude': '36.246',
#   'longitude': '-86.757',
#   'zip_code': '37207',
#   'rpa': '2011',
#   'zone': '721',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '780',
#   'offense_description': 'RECOVERY, STOLEN PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.757, 36.246]}},
#  {'primary_key': '20220003902_21',
#   'incident_number': '20220003902',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:13:00.000',
#   'incident_reported': '2022-01-04T00:13:00.000',
#   'incident_location': 'LEBANON PIKE',
#   'latitude': '36.19',
#   'longitude': '-86.63',
#   'rpa': '9601',
#   'zone': '525',
#   'location_code': '74',
#   'location_description': 'LOCKER ROOM',
#   'offense_number': '2',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.19]}},
#  {'primary_key': '20220003902_11',
#   'incident_number': '20220003902',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:13:00.000',
#   'incident_reported': '2022-01-04T00:13:00.000',
#   'incident_location': 'LEBANON PIKE',
#   'latitude': '36.19',
#   'longitude': '-86.63',
#   'rpa': '9601',
#   'zone': '525',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.63, 36.19]}},
#  {'primary_key': '20220003794_11',
#   'incident_number': '20220003794',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-03T20:30:00.000',
#   'incident_reported': '2022-01-03T20:30:00.000',
#   'incident_location': 'LAFAYETTE ST',
#   'latitude': '36.15',
#   'longitude': '-86.78',
#   'rpa': '4025',
#   'zone': '423',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '35A',
#   'offense_description': 'MARIJUANA - POSSESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.15]}}]

# %%
df = pd.DataFrame(res)
df
# Out:
#         primary_key incident_number report_type report_type_description  \
# 0    20220002526_11     20220002526           D              DISPATCHED
# 1    20220047605_11     20220047605           D              DISPATCHED
# 2    20220046961_11     20220046961           D              DISPATCHED
# 3    20220056911_11     20220056911           S                 SUSPECT
# 4    20220000685_11     20220000685           D              DISPATCHED
# ..              ...             ...         ...                     ...
# 995  20220003810_11     20220003810           D              DISPATCHED
# 996  20220003772_11     20220003772           D              DISPATCHED
# 997  20220003902_21     20220003902           D              DISPATCHED
# 998  20220003902_11     20220003902           D              DISPATCHED
# 999  20220003794_11     20220003794           S                 SUSPECT
#
#     incident_status_code incident_status_description investigation_status  \
# 0                      O                        OPEN                 Open
# 1                      U                   UNFOUNDED               Closed
# 2                      U                   UNFOUNDED               Closed
# 3                      O                        OPEN                 Open
# 4                      O                        OPEN                 Open
# ..                   ...                         ...                  ...
# 995                    A           CLEARED BY ARREST               Closed
# 996                    U                   UNFOUNDED               Closed
# 997                    O                        OPEN                 Open
# 998                    O                        OPEN                 Open
# 999                    O                        OPEN                 Open
#
#            incident_occurred        incident_reported incident_location  ...  \
# 0    2022-01-01T00:00:00.000  2022-01-03T00:50:00.000         4TH AVE N  ...
# 1    2022-01-01T00:00:00.000  2022-02-01T10:33:00.000         7716 7716  ...
# 2    2022-01-01T00:00:00.000  2022-02-01T02:52:00.000         2209 2209  ...
# 3    2022-01-01T00:00:00.000  2022-02-07T07:52:00.000       HOBSON PIKE  ...
# 4    2022-01-01T00:00:00.000  2022-01-01T13:43:00.000        SHELBY AVE  ...
# ..                       ...                      ...               ...  ...
# 995  2022-01-03T20:00:00.000  2022-01-03T22:04:00.000         3036 3036  ...
# 996  2022-01-03T20:01:00.000  2022-01-03T20:35:00.000         3458 3458  ...
# 997  2022-01-03T20:13:00.000  2022-01-04T00:13:00.000      LEBANON PIKE  ...
# 998  2022-01-03T20:13:00.000  2022-01-04T00:13:00.000      LEBANON PIKE  ...
# 999  2022-01-03T20:30:00.000  2022-01-03T20:30:00.000      LAFAYETTE ST  ...
#
#     victim_number domestic_related victim_type        victim_description  \
# 0               1            False           I  INDIVIDUAL (18 AND OVER)
# 1               1            False           I  INDIVIDUAL (18 AND OVER)
# 2               1            False           I  INDIVIDUAL (18 AND OVER)
# 3               1            False           S                   SOCIETY
# 4               1            False           I  INDIVIDUAL (18 AND OVER)
# ..            ...              ...         ...                       ...
# 995             1             True           I  INDIVIDUAL (18 AND OVER)
# 996             1            False           I  INDIVIDUAL (18 AND OVER)
# 997             1            False           I  INDIVIDUAL (18 AND OVER)
# 998             1            False           I  INDIVIDUAL (18 AND OVER)
# 999             1            False           S                   SOCIETY
#
#     victim_gender victim_race victim_ethnicity victim_county_resident  \
# 0               M           W     Non-Hispanic               RESIDENT
# 1               M           W         Hispanic               RESIDENT
# 2               M           B     Non-Hispanic               RESIDENT
# 3             NaN         NaN              NaN                    NaN
# 4               M           W     Non-Hispanic               RESIDENT
# ..            ...         ...              ...                    ...
# 995             F           B     Non-Hispanic           NON RESIDENT
# 996             F           W          Unknown               RESIDENT
# 997             F           W     Non-Hispanic               RESIDENT
# 998             F           W     Non-Hispanic               RESIDENT
# 999           NaN         NaN              NaN                    NaN
#
#                                        mapped_location zip_code
# 0    {'type': 'Point', 'coordinates': [-86.79, 36.17]}      NaN
# 1                                                  NaN    37080
# 2    {'type': 'Point', 'coordinates': [-86.82, 36.1...    37215
# 3     {'type': 'Point', 'coordinates': [-86.6, 36.05]}      NaN
# 4    {'type': 'Point', 'coordinates': [-86.74, 36.17]}      NaN
# ..                                                 ...      ...
# 995  {'type': 'Point', 'coordinates': [-86.823, 36....    37218
# 996  {'type': 'Point', 'coordinates': [-86.757, 36....    37207
# 997  {'type': 'Point', 'coordinates': [-86.63, 36.19]}      NaN
# 998  {'type': 'Point', 'coordinates': [-86.63, 36.19]}      NaN
# 999  {'type': 'Point', 'coordinates': [-86.78, 36.15]}      NaN
#
# [1000 rows x 31 columns]

# %% [markdown]
# 2. Using the [2020 American Community Survey API](https://www.census.gov/data/developers/data-sets/acs-5year.html), obtain, for each census tract, the population (B01001_001E in the detailed tables) and the median income (S1901_C01_012E in the subject tables). Hint: Tennessee's FIPS code is 47 and Davidson County's FIPS code is 37.

# %% [markdown]
# ### Part 2 - Spatial Joining and Data Merging

# %% [markdown]
# 3. Download the 2020 census tract shapefiles for Tennessee from https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.2020.html. (The FIPS code for Tennessee is 47). Perform a spatial join to determine the census tract in which each burglary incident occurred.

# %% [markdown]
# 4. Aggregate the data by census tract. **Warning:** each incident can appear multiple times if there are multiple victims, so be sure that you aren't double-counting any incidents. Which census tract had the highest number of burglaries? Which census tract had the highest number of burglaries per 1000 residents? **Note:** Make sure that you keep all census tracts, not just those that have had a burglary.

# %% [markdown]
# 5. Merge in the census data that you gathered in question 2. Remove any rows that have zero population or negative median income values.

# %% [markdown]
# ### Part 3 - Statistical Modeling

# %% [markdown]
# 6. Finally, we'll build some statistical models to see how well we can explain the number of aggravated burglaries using the median income of each census tract. Start with some EDA to look at the relationship between median income and number of aggravated burglaries.

# %% [markdown]
# 7. Fit a Poisson regression model with target variable the rate of burglaries per census tract and with predictor the median income. Offset using the log of the population so that we are looking at the rate of burglaries per population instead of the number of burglaries. How can you interpret the meaning of the output?

# %% [markdown]
# 8. **Bonus:** Try out a negative binomial model. To get started with a negative binomial model, you can check out [this tutorial](https://timeseriesreasoning.com/contents/negative-binomial-regression-model/). How does this model compare to the Poisson model?

# %% [markdown]
# Additional Resources for Generalized Linear Models:
# * DataCamp - [Generalized Linear Models in Python](https://learn.datacamp.com/courses/generalized-linear-models-in-python)
# * [Beyond Multiple Linear Regression, Chapter 4](https://bookdown.org/roback/bookdown-BeyondMLR/ch-poissonreg.html) Warning - the code in this book is all R, but the conceptual explanations are very clear.
# * [This set of notes](https://apwheele.github.io/MathPosts/PoissonReg.html#negative-binomial-when-the-poisson-does-not-fit), which talks about the problem of overdispersion.
